# %%
import pandas as pd
import numpy as np

import SimulationEngine
import PLScraper
import manipulate

from pandasql import sqldf
import datetime

# %%
lastseason_fpath="data/2022-23 PL/2023_matchday_results.csv"
lastseason=pd.read_csv(lastseason_fpath)

# %%
lastseason.head()
# Out:
#    Unnamed: 0  fixture.id               fixture.date  teams.home.id  \
# 0           0      867946  2022-08-05T19:00:00+00:00             52
# 1           1      867947  2022-08-06T11:30:00+00:00             36
# 2           2      867948  2022-08-06T14:00:00+00:00             35
# 3           3      867949  2022-08-06T14:00:00+00:00             63
# 4           4      867950  2022-08-07T13:00:00+00:00             46
#
#   teams.home.name teams.home.winner  teams.away.id teams.away.name  \
# 0  Crystal Palace             False             42         Arsenal
# 1          Fulham               NaN             40       Liverpool
# 2     Bournemouth              True             66     Aston Villa
# 3           Leeds              True             39          Wolves
# 4       Leicester               NaN             55       Brentford
#
#   teams.away.winner  goals.home  goals.away
# 0              True           0           2
# 1               NaN           2           2
# 2             False           2           0
# 3             False           2           1
# 4               NaN           2           2

# %%
oldcols=['fixture.date','teams.home.name','goals.home','teams.away.name','goals.away']
newcols=['Datetime','HomeTeam','HomeGoals','AwayTeam','AwayGoals']
lastseason=manipulate.rename_cols(lastseason,oldcols,newcols)
lastseason=lastseason[newcols]
lastseason['Status']='FT'

# %%
lastseason.head()
# Out:
#                     Datetime        HomeTeam  HomeGoals     AwayTeam  \
# 0  2022-08-05T19:00:00+00:00  Crystal Palace          0      Arsenal
# 1  2022-08-06T11:30:00+00:00          Fulham          2    Liverpool
# 2  2022-08-06T14:00:00+00:00     Bournemouth          2  Aston Villa
# 3  2022-08-06T14:00:00+00:00           Leeds          2       Wolves
# 4  2022-08-07T13:00:00+00:00       Leicester          2    Brentford
#
#    AwayGoals Status
# 0          2     FT
# 1          2     FT
# 2          0     FT
# 3          1     FT
# 4          2     FT

# %%
thisseason=PLScraper.scrape_pl_results()

# %%
thisseason.head()
# Out:
#              Datetime          HomeTeam HomeGoals           AwayTeam  \
# 0 2023-08-27 14:00:00           Burnley         1        Aston Villa
# 1 2023-08-27 14:00:00  Sheffield United         1    Manchester City
# 2 2023-08-27 16:30:00  Newcastle United         1          Liverpool
# 3 2023-08-26 12:30:00       Bournemouth         0  Tottenham Hotspur
# 4 2023-08-26 15:00:00           Arsenal         2             Fulham
#
#   AwayGoals Status
# 0         3     FT
# 1         2     FT
# 2         2     FT
# 3         2     FT
# 4         2     FT

# %%
from pandasql import sqldf

# %%
query='''
    WITH FINAL AS
    (
     SELECT Datetime, HomeTeam, HomeGoals, AwayTeam, AwayGoals, Status
    FROM lastseason
    
    UNION ALL
    
    SELECT Datetime, HomeTeam, HomeGoals, AwayTeam, AwayGoals, Status
    FROM thisseason
    WHERE
    Datetime > (SELECT MAX(Datetime) FROM lastseason)
    AND Status='FT'
    )
    SELECT *
    FROM FINAL
    ORDER BY Datetime DESC;
    '''

# %%
results_df=sqldf(query)

# %%
results_df
# Out:
#                        Datetime                  HomeTeam HomeGoals  \
# 0    2023-08-27 16:30:00.000000          Newcastle United         1
# 1    2023-08-27 14:00:00.000000                   Burnley         1
# 2    2023-08-27 14:00:00.000000          Sheffield United         1
# 3    2023-08-26 17:30:00.000000  Brighton and Hove Albion         1
# 4    2023-08-26 15:00:00.000000                   Arsenal         2
# ..                          ...                       ...       ...
# 404   2022-08-06T14:00:00+00:00                     Leeds         2
# 405   2022-08-06T14:00:00+00:00                 Newcastle         2
# 406   2022-08-06T14:00:00+00:00                 Tottenham         4
# 407   2022-08-06T11:30:00+00:00                    Fulham         2
# 408   2022-08-05T19:00:00+00:00            Crystal Palace         0
#
#               AwayTeam AwayGoals Status
# 0            Liverpool         2     FT
# 1          Aston Villa         3     FT
# 2      Manchester City         2     FT
# 3      West Ham United         3     FT
# 4               Fulham         2     FT
# ..                 ...       ...    ...
# 404             Wolves         1     FT
# 405  Nottingham Forest         0     FT
# 406        Southampton         1     FT
# 407          Liverpool         2     FT
# 408            Arsenal         2     FT
#
# [409 rows x 6 columns]

# %%
all_teams=pd.unique(results_df.HomeTeam)
print(len(all_teams))
print(sorted(all_teams))
# Out:
# 27
# ['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton', 'Brighton and Hove Albion', 'Burnley', 'Chelsea', 'Crystal Palace', 'Everton', 'Fulham', 'Leeds', 'Leicester', 'Liverpool', 'Manchester City', 'Manchester United', 'Newcastle', 'Newcastle United', 'Nottingham Forest', 'Sheffield United', 'Southampton', 'Tottenham', 'Tottenham Hotspur', 'West Ham', 'West Ham United', 'Wolverhampton Wanderers', 'Wolves']

# %%
print(sorted(pd.unique(lastseason.HomeTeam)))
# Out:
# ['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton', 'Chelsea', 'Crystal Palace', 'Everton', 'Fulham', 'Leeds', 'Leicester', 'Liverpool', 'Manchester City', 'Manchester United', 'Newcastle', 'Nottingham Forest', 'Southampton', 'Tottenham', 'West Ham', 'Wolves']

# %%
prevnames=['Brighton','Newcastle','Tottenham','West Ham']
newnames=['Brighton and Hove Albion', 'Newcastle United', 'Tottenham Hotspur', 'West Ham United']

results_df=manipulate.df_rename_vals(results_df,['HomeTeam','AwayTeam'],prevnames,newnames)
results_df=manipulate.df_strings_to_numbers(results_df,['HomeGoals','AwayGoals'])

# %%
all_teams=pd.unique(results_df.HomeTeam)
print(len(all_teams))
print(sorted(all_teams))
# Out:
# 23
# ['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton and Hove Albion', 'Burnley', 'Chelsea', 'Crystal Palace', 'Everton', 'Fulham', 'Leeds', 'Leicester', 'Liverpool', 'Manchester City', 'Manchester United', 'Newcastle United', 'Nottingham Forest', 'Sheffield United', 'Southampton', 'Tottenham Hotspur', 'West Ham United', 'Wolverhampton Wanderers', 'Wolves']

# %%
fixture_df=PLScraper.scrape_pl_fixtures()

# %%
sim_until_date=datetime.datetime.now()+datetime.timedelta(days=7)
fixture_df=fixture_df[fixture_df.Datetime<sim_until_date]

# %%
fixture_df
# Out:
#              Datetime                  HomeTeam HomeGoals  \
# 0 2023-09-01 20:00:00                Luton Town         0
# 1 2023-09-02 12:30:00          Sheffield United         0
# 2 2023-09-02 15:00:00                 Brentford         0
# 3 2023-09-02 15:00:00                   Burnley         0
# 4 2023-09-02 15:00:00                   Chelsea         0
# 5 2023-09-02 15:00:00           Manchester City         0
# 6 2023-09-02 17:30:00  Brighton and Hove Albion         0
# 7 2023-09-03 14:00:00            Crystal Palace         0
# 8 2023-09-03 14:00:00                 Liverpool         0
# 9 2023-09-03 16:30:00                   Arsenal         0
#
#                   AwayTeam AwayGoals
# 0          West Ham United         0
# 1                  Everton         0
# 2              Bournemouth         0
# 3        Tottenham Hotspur         0
# 4        Nottingham Forest         0
# 5                   Fulham         0
# 6         Newcastle United         0
# 7  Wolverhampton Wanderers         0
# 8              Aston Villa         0
# 9        Manchester United         0

# %%
SimulationEngine.predict_multiple_results(fixture_df,results_df)
# Out:
#              Datetime                  HomeTeam                 AwayTeam  \
# 0 2023-09-01 20:00:00                Luton Town          West Ham United
# 1 2023-09-02 12:30:00          Sheffield United                  Everton
# 2 2023-09-02 15:00:00                 Brentford              Bournemouth
# 3 2023-09-02 15:00:00                   Burnley        Tottenham Hotspur
# 4 2023-09-02 15:00:00                   Chelsea        Nottingham Forest
# 5 2023-09-02 15:00:00           Manchester City                   Fulham
# 6 2023-09-02 17:30:00  Brighton and Hove Albion         Newcastle United
# 7 2023-09-03 14:00:00            Crystal Palace  Wolverhampton Wanderers
# 8 2023-09-03 14:00:00                 Liverpool              Aston Villa
# 9 2023-09-03 16:30:00                   Arsenal        Manchester United
#
#    ProbHomeWin  ProbAwayWin  ProbDraw FullSimulatedResults
# 0        0.136        0.741     0.123                 None
# 1        0.354        0.425     0.221                 None
# 2        0.700        0.152     0.148                 None
# 3        0.178        0.699     0.123                 None
# 4        0.348        0.492     0.160                 None
# 5        0.612        0.222     0.166                 None
# 6        0.358        0.443     0.199                 None
# 7        0.555        0.241     0.204                 None
# 8        0.519        0.283     0.198                 None
# 9        0.395        0.401     0.204                 None
